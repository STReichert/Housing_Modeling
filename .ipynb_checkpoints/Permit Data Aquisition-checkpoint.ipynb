# %%
import requests
import pandas as pd
import json
import geopandas as gpd

# %%
url = 'https://data.lacity.org/resource/nbyu-2ha9.geojson'

# %%
gdf = gpd.read_file(url)
gdf.head()
# Out:
#   assessor_parcel zip_code location_1_address work_description  \
# 0             016    90043                                None
# 1             008    90004                                None
# 2             048    91604                                None
# 3             001    90029                                None
# 4             005    90039                                None
#
#   applicant_address_3 floor_area_l_a_zoning_code_definition  \
# 0        VAN NUYS, CA                                  None
# 1          ARLETA, CA                                  None
# 2          RESEDA, CA                                  None
# 3          RESEDA, CA                                  None
# 4      SUN VALLEY, CA                                  None
#
#   address_fraction_end project_number suffix_direction of_stories  \
# 0                 None           None             None       None
# 1                 None           None             None       None
# 2                 None           None             None       None
# 3                 None           None             None       None
# 4                 None           None             None       None
#
#   address_start permit_category          status_date unit_range_end  \
# 0          5334   No Plan Check  2013-01-04T00:00:00           None
# 1           617   No Plan Check  2013-01-07T00:00:00           None
# 2          3651   No Plan Check  2015-04-30T00:00:00           None
# 3          4929   No Plan Check  2013-01-08T00:00:00           None
# 4          2537   No Plan Check  2013-01-04T00:00:00           None
#
#          pcis_permit address_end           issue_date   street_name  \
# 0  13041-90000-00002        5334  2013-01-01T00:00:00       CHESLEY
# 1  13042-90000-00003         617  2013-01-01T00:00:00  COMMONWEALTH
# 2  13042-90000-00005        3651  2013-01-01T00:00:00     ALTA MESA
# 3  13042-90000-00006        4929  2013-01-01T00:00:00       MELROSE
# 4  13042-90000-00001        2537  2013-01-01T00:00:00      PANORAMA
#
#      contractor_address license     contractors_business_name assessor_page  \
# 0        6959 VARNA AVE  876625       MEGA POWER ELECTRIC INC           001
# 1      8561 SNOWDEN AVE  743493  MC SAVANEY THOMAS H PLUMBING           026
# 2  18813 VANOWEN STREET  813217       A - 1 APEX PLUMBING INC           021
# 3  18813 VANOWEN STREET  813217       A - 1 APEX PLUMBING INC           028
# 4           P O BOX 398  705233       AKHOIAN ENTERPRISES INC           007
#
#   block applicant_first_name location_1_city applicant_last_name valuation  \
# 0  None               GERMAN                          NESTERENKO      None
# 1     B               THOMAS                           MCSAVANEY      None
# 2  None               MICHEL                               GABAY      None
# 3  None               MICHEL                               GABAY      None
# 4  None                 JOHN                             AKHOIAN      None
#
#   unit_range_start                 tract address_fraction_start  \
# 0             None                TR 911                   None
# 1       617&6171/2  DAYTON HEIGHTS TRACT                   None
# 2             None               TR 6293                   None
# 3             None               TR 1186                   None
# 4             None               TR 8423                   None
#
#   location_1_state principal_last_name contractor_city   latest_status  \
# 0                           NESTERENKO        VAN NUYS  Permit Finaled
# 1                           MC SAVANEY          ARLETA  Permit Finaled
# 2                                GABAY          RESEDA  Permit Finaled
# 3                                GABAY          RESEDA  Permit Finaled
# 4                              AKHOIAN      SUN VALLEY  Permit Finaled
#
#   census_tract  lot floor_area_l_a_building_code_definition  \
# 0      2346.00  247                                       0
# 1      1927.00    9                                       0
# 2      1439.01   96                                       0
# 3      1916.10   28                                       0
# 4      1951.00  220                                       0
#
#      applicant_address_1 street_suffix applicant_business_name  \
# 0         6959 VARNA AVE           AVE                    None
# 1       8561 SNOWDEN AVE           AVE                    None
# 2     18813 W VANOWEN ST            DR                    None
# 3     18813 W VANOWEN ST          HILL                    None
# 4  8847 LANKERSHIM BLVD.           TER                    None
#
#   street_direction permit_type occupancy location_1_zip principal_middle_name  \
# 0                S  Electrical      None                                 None
# 1                N    Plumbing      None                               HAROLD
# 2                N    Plumbing      None                                 None
# 3                W    Plumbing      None                                 None
# 4                N    Plumbing      None                                 JOHN
#
#   assessor_book of_residential_dwelling_units principal_first_name       zone  \
# 0          5007                          None               GERMAN       R1-1
# 1          5539                          None               THOMAS       R2-1
# 2          2384                          None               MICHEL       R1-1
# 3          5535                          None               MICHEL  R1-1-HPOZ
# 4          5432                          None               OGANES     R1-1VL
#
#   initiating_office license_type event_code reference_old_permit  \
# 0          INTERNET          C10       None                 None
# 1          INTERNET          C36       None                 None
# 2          INTERNET          C36       None                 None
# 3          INTERNET          C36       None                 None
# 4          INTERNET          C36       None                 None
#
#   contractor_state license_expiration_date applicant_address_2  \
# 0               CA     2014-07-31T00:00:00                None
# 1               CA     2013-12-31T00:00:00                None
# 2               CA     2014-09-30T00:00:00                None
# 3               CA     2014-09-30T00:00:00                None
# 4               CA     2013-05-31T00:00:00                None
#
#           permit_sub_type                     geometry
# 0  1 or 2 Family Dwelling  POINT (-118.33429 33.99393)
# 1  1 or 2 Family Dwelling  POINT (-118.28576 34.08229)
# 2  1 or 2 Family Dwelling  POINT (-118.40898 34.13638)
# 3  1 or 2 Family Dwelling  POINT (-118.30644 34.08528)
# 4  1 or 2 Family Dwelling  POINT (-118.27098 34.10561)

# %%
pd.set_option('display.max_columns', 500)

# %%
gdf['permit_type'].unique()
# Out:
# array(['Electrical', 'Plumbing', 'HVAC', 'Bldg-Alter/Repair', 'Elevator',
#        'Bldg-Addition', 'Grading', 'Fire Sprinkler', 'Nonbldg-New',
#        'Nonbldg-Alter/Repair', 'Bldg-New', 'Swimming-Pool/Spa',
#        'Bldg-Demolition', 'Sign'], dtype=object)

# %%
gdf['permit_sub_type'].unique()
# Out:
# array(['1 or 2 Family Dwelling', 'Commercial', 'Apartment', 'Onsite',
#        'Public Safety Only', 'Special Equipment'], dtype=object)

# %%
gdf[gdf['permit_type'] == 'Bldg-Alter/Repair']
# Out:
#     assessor_parcel zip_code location_1_address  \
# 13              016    90043
# 19              017    91423
# 22              047    90210
# 27              066    90292
# 28              042    90045
# ..              ...      ...                ...
# 985             009    90065
# 987             032    91352
# 993             002    90005
# 994             006    90069
# 998             003    90019
#
#                                       work_description applicant_address_3  \
# 13                                       DRYWALL PATCH                None
# 19   INTERIOR REMODEL OF SFD.  REMOVE 2 NON-BEARING...                None
# 22   Re-roof with Class A or B material weighing le...                None
# 27   (4) KITCHENS & (4) BATHROOMS REMODEL (FOR RESI...                None
# 28   CONSTRUCT NEW MIXED-USE OF RETAILS AND 4-STORY...    SANTA MONICA, CA
# ..                                                 ...                 ...
# 985  REFRAME ROOF OVER (E) GARAGE.  WORK TO INCLUDE...         GARDENA, CA
# 987  BURBANK AIRPORT RESIDENTIAL SOUND TREATMENT PR...                None
# 993  COMPLETE WORK STARTED THROUGH #13016-10000-002...                None
# 994  bathroom remodel for residential buildings (no...                None
# 998  Interior bathroom remodel/repair (no changes i...        GLENDALE, CA
#
#     floor_area_l_a_zoning_code_definition address_fraction_end project_number  \
# 13                                   None                 None           None
# 19                                   None                 None           None
# 22                                   None                 None           None
# 27                                   None                 None           None
# 28                                   None                 None           None
# ..                                    ...                  ...            ...
# 985                                  None                 None           None
# 987                                  None                 None           None
# 993                                  None                 None           None
# 994                                  None                 None           None
# 998                                  None                 None           None
#
#     suffix_direction of_stories address_start permit_category  \
# 13              None       None          5334   No Plan Check
# 19              None       None          4053      Plan Check
# 22              None       None          1470   No Plan Check
# 27              None       None         13603   No Plan Check
# 28              None       None          7270      Plan Check
# ..               ...        ...           ...             ...
# 985             None       None          3363      Plan Check
# 987             None       None          7232   No Plan Check
# 993             None       None          2916   No Plan Check
# 994             None       None          1311   No Plan Check
# 998             None       None          1355   No Plan Check
#
#              status_date unit_range_end        pcis_permit address_end  \
# 13   2013-01-15T00:00:00           None  13016-20000-00061        5334
# 19   2013-02-14T00:00:00           None  13016-20000-00048        4053
# 22   2013-01-07T00:00:00           None  13016-20000-00072        1470
# 27   2015-01-27T00:00:00           None  13016-30000-00062       13603
# 28   2015-05-13T00:00:00           None  11010-10001-02451        7270
# ..                   ...            ...                ...         ...
# 985  2013-01-18T00:00:00           None  12016-70000-25878        3363
# 987  2013-03-04T00:00:00           None  12016-10000-25968        7232
# 993  2014-01-28T00:00:00           None  13016-10000-00250        2916
# 994  2013-02-22T00:00:00           None  13016-20000-00229        1311
# 998  2013-02-08T00:00:00           None  13016-90000-00261        1355
#
#               issue_date    street_name          contractor_address license  \
# 13   2013-01-02T00:00:00        CHESLEY  1223 WILSHIRE BLVD STE 172  842003
# 19   2013-01-02T00:00:00        WOODMAN           6919 JAMIESON AVE  937376
# 22   2013-01-02T00:00:00         LAUREL           2725 ATLAS AVENUE  571598
# 27   2013-01-02T00:00:00  MARINA POINTE     21480 PACIFIC BLVD #100  837358
# 28   2013-01-02T00:00:00     MANCHESTER            555 FIRST STREET  302007
# ..                   ...            ...                         ...     ...
# 985  2013-01-04T00:00:00       ROSEVIEW        731 EAST 75TH STREET  965193
# 987  2013-01-04T00:00:00     CARTWRIGHT   315 SOUTH FRANKLIN STREET  796968
# 993  2013-01-04T00:00:00        FRANCIS                        None       0
# 994  2013-01-04T00:00:00   SUNSET PLAZA  15145 CALIFA STREET UNIT B  784036
# 998  2013-01-04T00:00:00       TREMAINE        3518 OCEAN VIEW BLVD  704369
#
#                      contractors_business_name assessor_page block  \
# 13                    RELIABLE REMODELLERS INC           001  None
# 19                            NOAH CONSTRCTION           024  None
# 22   WILSON WILLIAM CONSTRUCTION & DEVELOPMENT           015  None
# 27         PARAMOUNT CONSTRUCTION SERVICES INC           003  None
# 28                           BERNARDS BROS INC           026  None
# ..                                         ...           ...   ...
# 985                  GOLDEN POINT CONSTRUCTION           026  None
# 987            S & L SPECIALTY CONTRACTING INC           021  None
# 993                              OWNER-BUILDER           024  None
# 994                          ONE WEEK BATH INC           002  None
# 998                           CTR BUILDERS INC           021  None
#
#     applicant_first_name location_1_city applicant_last_name valuation  \
# 13                 VERED                                None       501
# 19         STUDIO DESIGN                                None     10000
# 22                  None                                None      4000
# 27                  GREG                             COLLINS     12000
# 28                  GARY                                LEUS       501
# ..                   ...             ...                 ...       ...
# 985               JAVIER                             VASQUEZ      5000
# 987                 None                                None      5360
# 993                YOUNG                                 KIM      9000
# 994                ROBIN                          KUYKENDALL      8000
# 998                 IRMA                               CLARK      6200
#
#     unit_range_start                          tract address_fraction_start  \
# 13              None                         TR 911                   None
# 19              None                        TR 7633                   None
# 22              None                       TR 25195                   None
# 27              None                    TRACT NO. 4                   None
# 28             1-260                         P M 72                   None
# ..               ...                            ...                    ...
# 985             None  BOWEN'S PLEASANT VIEW TERRACE                   None
# 987             None                       TR 10700                   None
# 993             None           FRANCIS AVENUE TRACT                   None
# 994             None                       TR 17290                   None
# 998             None                        TR 4604                   None
#
#     location_1_state principal_last_name contractor_city   latest_status  \
# 13                               SHETZEN    SANTA MONICA  Permit Finaled
# 19                           HASSANZADEH          RESEDA  Permit Finaled
# 22                                WILSON   THOUSAND OAKS  Permit Finaled
# 27                         CHRISTOPOULOS        STERLING  Permit Expired
# 28                              BERNARDS    SAN FERNANDO  Permit Finaled
# ..               ...                 ...             ...             ...
# 985                                MEJIA     LOS ANGELES  Permit Finaled
# 987                                LEANA        SYRACUSE  Permit Finaled
# 993                                 None            None  Permit Finaled
# 994                             PLASKOFF        VAN NUYS  Permit Finaled
# 998                                CLARK        GLENDALE  Permit Finaled
#
#     census_tract                         lot  \
# 13       2346.00                         247
# 19       1417.00                          44
# 22       2611.02                          18
# 27       2741.00  FRANCISCO MACHADO 40 ACRES
# 28       2766.04                           D
# ..           ...                         ...
# 985      1853.10                          77
# 987      1230.20                          26
# 993      2122.02                          16
# 994      1943.00                          50
# 998      2172.00                         458
#
#     floor_area_l_a_building_code_definition   applicant_address_1  \
# 13                                     None                  None
# 19                                     None                  None
# 22                                     None                  None
# 27                                     None                  None
# 28                                     None         1730 BERKELEY
# ..                                      ...                   ...
# 985                                    None    841 W. GARDENA BL.
# 987                                    None                  None
# 993                                    None                  None
# 994                                    None                  None
# 998                                    None  3518 OCEAN VIEW BLVD
#
#     street_suffix applicant_business_name street_direction        permit_type  \
# 13            AVE                    None                S  Bldg-Alter/Repair
# 19            CYN                    None                N  Bldg-Alter/Repair
# 22            WAY                    None                N  Bldg-Alter/Repair
# 27             DR                    None                W  Bldg-Alter/Repair
# 28            AVE                    VTBS                W  Bldg-Alter/Repair
# ..            ...                     ...              ...                ...
# 985           AVE                    None                E  Bldg-Alter/Repair
# 987           AVE                    None                N  Bldg-Alter/Repair
# 993           AVE                    None                W  Bldg-Alter/Repair
# 994            DR                    None                N  Bldg-Alter/Repair
# 998           AVE                    None                S  Bldg-Alter/Repair
#
#     occupancy location_1_zip principal_middle_name assessor_book  \
# 13       None                                 None          5007
# 19       None                                 None          2272
# 22       None                              FRANCIS          4355
# 27       None                          CONSTANTINE          4229
# 28       None                                 DEAN          4119
# ..        ...            ...                   ...           ...
# 985      None                                AVIEL          5454
# 987      None                              WALLACE          2410
# 993      None                                 None          5077
# 994      None                                 DORE          5560
# 998      None                                 SANZ          5083
#
#     of_residential_dwelling_units principal_first_name              zone  \
# 13                           None               JOSEPH              R1-1
# 19                           None              BEHROOZ              R1-1
# 22                           None              WILLIAM          RE15-1-H
# 27                           None                  TOM         C4(OX)-2D
# 28                           None              DOUGLAS  (T)(Q)RAS4-1-CDO
# ..                            ...                  ...               ...
# 985                          None               YULMAN          R1-1-CDO
# 987                          None                JAMES              R1-1
# 993                          None                 None              R4-1
# 994                          None              MATTHEW          RE15-1-H
# 998                          None                 IRMA            R2-1-O
#
#     initiating_office license_type event_code reference_old_permit  \
# 13           VAN NUYS            B       None            13VN50602
# 19           VAN NUYS            B       None            13VN50599
# 22           VAN NUYS            B       None            13VN50611
# 27            WEST LA            B       None            13WL50265
# 28              METRO            B       None            13LA11080
# ..                ...          ...        ...                  ...
# 985          SOUTH LA            B       None            13LA11184
# 987             METRO            B       None            13LA11196
# 993             METRO           NA       None            13LA11214
# 994          VAN NUYS            B       None            13VN50726
# 998          INTERNET            B       None            13OL11189
#
#     contractor_state license_expiration_date applicant_address_2  \
# 13                CA     2014-04-30T00:00:00                None
# 19                CA     2013-09-30T00:00:00                None
# 22                CA     2013-06-30T00:00:00                None
# 27                VA     2014-04-30T00:00:00                None
# 28                CA     2013-03-31T00:00:00                None
# ..               ...                     ...                 ...
# 985               CA     2013-09-30T00:00:00                None
# 987               NY     2013-07-31T00:00:00                None
# 993             None                    None                None
# 994               CA     2014-09-30T00:00:00                None
# 998               CA     2013-03-31T00:00:00                None
#
#             permit_sub_type                     geometry
# 13   1 or 2 Family Dwelling  POINT (-118.33429 33.99393)
# 19   1 or 2 Family Dwelling  POINT (-118.43026 34.14345)
# 22   1 or 2 Family Dwelling  POINT (-118.41759 34.09903)
# 27                Apartment  POINT (-118.44433 33.98559)
# 28                Apartment  POINT (-118.42143 33.95959)
# ..                      ...                          ...
# 985  1 or 2 Family Dwelling  POINT (-118.22538 34.09580)
# 987  1 or 2 Family Dwelling  POINT (-118.36328 34.20215)
# 993  1 or 2 Family Dwelling  POINT (-118.28969 34.05670)
# 994  1 or 2 Family Dwelling  POINT (-118.38328 34.09572)
# 998  1 or 2 Family Dwelling  POINT (-118.34048 34.04977)
#
# [248 rows x 58 columns]

# %% [markdown]
# The problem is that the socrata api will only let me query 1000 rows at a time. There is some information on [this blogpost](https://support.socrata.com/hc/en-us/articles/202949268-How-to-query-more-than-1000-rows-of-a-dataset)
#
# If we use the sodapy package I can set the limit to 50,000 I think which would definitely be helpful. There is also more information [here](https://dev.socrata.com/foundry/data.lacity.org/yv23-pmwf) about using filters and SoQL queries to pull specific data. I think it will be helpful to pick a few parameters to target the data
#
# Some more specific API docs are [here](https://dev.socrata.com/docs/queries/). This also has good info on using SoQL to build a query into the API call which I think we'll need to do
#
# [More specific info for the precise data set](https://dev.socrata.com/foundry/data.lacity.org/yv23-pmwf)

# %% [markdown]
# All of this said, I am trying to better understand what paramaters from this data set are useful to us, I feel like there is just not a ton here.
# Maybe:
# - cost of work being done
# - when work was being done
# - type of work
# - something to do with the contractor?
#
# types of alternative data on the LA Data portal
# - forclosure properties
# - Zoning and land use
# - Affordable Housing Info
# - [Redlining](https://geohub.lacity.org/datasets/lacounty::la-county-home-owners-loan-corporation-holc-redlining/explore?location=34.004390%2C-118.156603%2C10.76)
# - [Index of displacement preasure](https://geohub.lacity.org/datasets/lahub::los-angeles-index-of-displacement-pressure/about) (The urban displacement project has a good index for displacement risk by census tract though too

# %%
#Setting up querries with multiple conditions or statements seemed easier using sodapy than a just the api url
from sodapy import Socrata

# %%
client = Socrata('data.lacity.org', None)
#This query could easily be edited to refine the column selection, or add expand the data filtering with where conditions
query = """
select
    *
where
    permit_type = 'Bldg-New'
limit
    100000
"""
results = client.get('nbyu-2ha9', content_type='geojson',
                    query=query)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#the sodapy client returns a result dictionary instead of a geojson file so it is trickier to load into a data frame
#I found information on extracting from features here: 
#https://stackoverflow.com/questions/45552955/loading-json-into-a-geodataframe

gdf2 = gpd.GeoDataFrame.from_features(results['features'])
#A number of records have "None" as geometry 
gdf2.geometry[gdf2['geometry']!=None].count()
# Out:
# 27513

# %%
gdf2.shape
# Out:
# (34738, 58)

# %%
# I select only those that have geometry listed
permit_gdf = gdf2[gdf2['geometry']!=None]

# %%
permit_gdf.set_crs('EPSG:4326', inplace=True)
permit_gdf.head()
# Out:
# /Users/seth/opt/anaconda3/envs/uds/lib/python3.8/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#                       geometry assessor_parcel zip_code location_1_address  \
# 1  POINT (-118.33547 34.08552)             029    90038
# 3  POINT (-118.29340 34.02109)             013    90007
# 5  POINT (-118.57742 34.28433)             033    91326
# 6  POINT (-118.43733 34.00514)             008    90066
# 8  POINT (-118.33069 34.02500)             010    90018
#
#                                     work_description applicant_address_3  \
# 1  New 3-Story Duplex w/Attached 2-Car Garage Eac...                None
# 3  BUILDING "B" - NEW (3) STORY DUPLEX BUILDING A...        LAWNDALE, CA
# 5  TWO STORY SFD WITH ATTACHED 3 CAR GARAGE _STAN...        PORTER RANCH
# 6          New SFD with attached garage and recroom.                None
# 8    NEW TWO STORY DUPLEX WITH OPEN PARKING AT REAR.                None
#
#   floor_area_l_a_zoning_code_definition address_fraction_end project_number  \
# 1                                  2328                 None           None
# 3                                  4963                  1/2           None
# 5                                  4957                 None           None
# 6                                  5994                 None           None
# 8                                  2444                  1/2           None
#
#   suffix_direction  ... principal_first_name       zone initiating_office  \
# 1             None  ...                 None  RD1.5-1XL             METRO
# 3             None  ...                 IHAB    RD1.5-1             METRO
# 5             None  ...               ROBERT    [T]RE-1          VAN NUYS
# 6             None  ...                DIANE       R1-1           WEST LA
# 8             None  ...                KAREN    RD1.5-1          SOUTH LA
#
#   license_type event_code reference_old_permit contractor_state  \
# 1           NA       None            21ON 5529             None
# 3            B       None            19LA18985               CA
# 5            B       None            20VN16086               PA
# 6            B       None            17WL80489               CA
# 8            B       None            18VN71708               CA
#
#    license_expiration_date applicant_address_2         permit_sub_type
# 1  2000-01-01T00:00:00.000                None  1 or 2 Family Dwelling
# 3  2019-10-31T00:00:00.000                None  1 or 2 Family Dwelling
# 5  2021-02-28T00:00:00.000                None  1 or 2 Family Dwelling
# 6  2018-05-31T00:00:00.000                None  1 or 2 Family Dwelling
# 8  2019-12-31T00:00:00.000                None  1 or 2 Family Dwelling
#
# [5 rows x 58 columns]

# %%
import matplotlib.pyplot as plt

import contextily as ctx
import numpy as np
from scipy import ndimage

# %%
fig, ax = plt.subplots(figsize=(12,12))
permit_gdf.plot(markersize=1, ax=ax)
ctx.add_basemap(ax, crs=permit_gdf.crs.to_string())

# %%
# Heatmap adapted from: https://nbviewer.org/gist/perrygeo/c426355e40037c452434

def heatmap(d, bins=(100,100), smoothing=1.3, cmap='jet', alpha=.3, title='title'):
    def getx(pt):
        return pt.coords[0][0]

    def gety(pt):
        return pt.coords[0][1]

    x = list(d.geometry.apply(getx))
    y = list(d.geometry.apply(gety))
    heatmap, xedges, yedges = np.histogram2d(y, x, bins=bins)
    extent = [yedges[0], yedges[-1], xedges[-1], xedges[0]]

    logheatmap = np.log(heatmap)
    logheatmap[np.isneginf(logheatmap)] = 0
    logheatmap = ndimage.filters.gaussian_filter(logheatmap, smoothing, mode='nearest')
    
    fig, ax = plt.subplots(figsize=(12,12))
    
    plt.imshow(logheatmap, cmap=cmap, extent=extent, alpha=alpha, zorder=15)
    ctx.add_basemap(ax, crs=d.crs.to_string())
    ax.set_title(title, fontsize=18)
    plt.colorbar()
    plt.gca().invert_yaxis()
    
    plt.show()

# %%
heatmap(permit_gdf, bins=(150,150), smoothing=2, cmap='hot', alpha=.6, title='Hotspots of New Construction in L.A. 2013-Present')
# Out:
# /var/folders/kz/8hthyz657tlbhl0x92mmdj2r0000gn/T/ipykernel_5342/1699189640.py:15: RuntimeWarning: divide by zero encountered in log
#   logheatmap = np.log(heatmap)
# /var/folders/kz/8hthyz657tlbhl0x92mmdj2r0000gn/T/ipykernel_5342/1699189640.py:17: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   logheatmap = ndimage.filters.gaussian_filter(logheatmap, smoothing, mode='nearest')
