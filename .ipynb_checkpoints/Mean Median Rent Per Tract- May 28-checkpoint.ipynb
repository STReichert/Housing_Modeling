# %% [markdown]
# # Finding Mean and Median Rent per Tract
# ## Also looking at average square foot or average rooms

# %%
import pandas as pd
import geopandas as gpd

joined = pd.read_csv('data/JOINED_CENSUS_LISTINGS_MAY_27.csv')
joined.head()
# Out:
#    Unnamed: 0  index_left            posted       neighborhood  \
# 0           0      1526.0  2022-05-23 18:03   (Marina del Rey)
# 1           0      2020.0  2022-05-23 09:47   (Marina del Rey)
# 2           0      2647.0  2022-05-21 13:45   (Marina Del Rey)
# 3           1        47.0  2022-05-25 12:16     (Venice Beach)
# 4           1        48.0  2022-05-25 12:15     (Venice Beach)
#
#                                           post title  number bedrooms    sqft  \
# 0  Pristine 3Bd, 2 Ba Townhouse In Marina Del Rey...              3.0  1500.0
# 1  3 Bedroom Furnished Marina del Rey Peninsula/V...              3.0  1850.0
# 2  Marina del Rey Beach Furnished 3 bedroom 3 bat...              3.0  1800.0
# 3  Recently Updated 3 Bedroom 2 Bath Quiet Walk S...              3.0  1400.0
# 4  Recently Updated 3 Bedroom 2 Bath Quiet Walk S...              3.0  1400.0
#
#                                                  URL  price  \
# 0  https://losangeles.craigslist.org/wst/apa/d/ma...  6,500
# 1  https://losangeles.craigslist.org/wst/apa/d/ve...  7,200
# 2  https://losangeles.craigslist.org/wst/apa/d/ve...  6,995
# 3  https://losangeles.craigslist.org/wst/apa/d/ve...  5,500
# 4  https://losangeles.craigslist.org/wst/apa/d/ve...  5,500
#
#                          latlon  ...  EducProf  EducDoct     PctNHW  \
# 0  ['33.976661', '-118.462111']  ...     411.0     247.0  77.964519
# 1  ['33.976739', '-118.462411']  ...     411.0     247.0  77.964519
# 2  ['33.979506', '-118.464868']  ...     411.0     247.0  77.964519
# 3  ['33.980825', '-118.467207']  ...     258.0      99.0  87.822791
# 4  ['33.980825', '-118.467207']  ...     258.0      99.0  87.822791
#
#    PctBlackAA  PctAsian     pctPOC  PctBachelor  PctMasters  PctDoctorate  \
# 0    2.054155  8.216620  22.035481    34.970946   27.284733      6.524036
# 1    2.054155  8.216620  22.035481    34.970946   27.284733      6.524036
# 2    2.054155  8.216620  22.035481    34.970946   27.284733      6.524036
# 3    1.800521  3.837953  12.177209    43.043599   23.965565      2.749236
# 4    1.800521  3.837953  12.177209    43.043599   23.965565      2.749236
#
#                         geometry
# 0  POINT (-118.462111 33.976661)
# 1  POINT (-118.462411 33.976739)
# 2  POINT (-118.464868 33.979506)
# 3  POINT (-118.467207 33.980825)
# 4  POINT (-118.467207 33.980825)
#
# [5 rows x 38 columns]

# %%
df1=pd.read_csv('Data/la_apts_SFV_geometry_May27.csv')
df2=pd.read_csv('Data/wst_5-25_geometry.csv')
df3=pd.read_csv('Data/lac_5-23_latlong.csv')
df4=pd.read_csv('Data/sgv_latlong.csv')
df5=pd.read_csv('Data/lgb_latlong.csv')

# %%
df1['x']=df1['x']*-1

# %%
df=pd.concat([df1, df2, df3, df4, df5])

# %%
df = df.drop(columns=['Unnamed: 0.1','Unnamed: 0'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13525 entries, 0 to 2338
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   posted           13525 non-null  object
#  1   neighborhood     13525 non-null  object
#  2   post title       13525 non-null  object
#  3   number bedrooms  11331 non-null  float64
#  4   sqft             11295 non-null  float64
#  5   URL              13525 non-null  object
#  6   price            13270 non-null  object
#  7   latlon           13525 non-null  object
#  8   y                13525 non-null  float64
#  9   x                13525 non-null  float64
# dtypes: float64(4), object(6)
# memory usage: 1.1+ MB

# %%
df.to_csv('Data/updated_joins_MAY_28.csv')

# %%
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.x, df.y))

# %%
la=gpd.read_file('Data/lacounty_clipped.geojson')

# %%
#joining to clipped la county geojson file so that only the listings in 
#Los Angeles city boundaries are kept
geojoin=gpd.sjoin(gdf.set_crs(epsg=4326),la,how='right', predicate='intersects')

# %%
geojoin.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 7551 entries, 0 to 1148
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index_left       6902 non-null   float64
#  1   posted           6902 non-null   object
#  2   neighborhood     6902 non-null   object
#  3   post title       6902 non-null   object
#  4   number bedrooms  5506 non-null   float64
#  5   sqft             5633 non-null   float64
#  6   URL              6902 non-null   object
#  7   price            6784 non-null   object
#  8   latlon           6902 non-null   object
#  9   y                6902 non-null   float64
#  10  x                6902 non-null   float64
#  11  GEOID            7551 non-null   object
#  12  TotalPop         7551 non-null   float64
#  13  WhitePop         7551 non-null   float64
#  14  BlackorAA        7551 non-null   float64
#  15  AmInd_AKnative   7551 non-null   float64
#  16  Asian            7551 non-null   float64
#  17  Hawaiian_PI      7551 non-null   float64
#  18  Other            7551 non-null   float64
#  19  EducTotal        7551 non-null   float64
#  20  Median HHI       7521 non-null   float64
#  21  NAME             7551 non-null   object
#  22  state            7551 non-null   object
#  23  county           7551 non-null   object
#  24  tract            7551 non-null   object
#  25  EducBachelor     7551 non-null   float64
#  26  EducMasters      7551 non-null   float64
#  27  EducProf         7551 non-null   float64
#  28  EducDoct         7551 non-null   float64
#  29  PctNHW           7530 non-null   float64
#  30  PctBlackAA       7530 non-null   float64
#  31  PctAsian         7530 non-null   float64
#  32  pctPOC           7530 non-null   float64
#  33  PctBachelor      7529 non-null   float64
#  34  PctMasters       7529 non-null   float64
#  35  PctDoctorate     7529 non-null   float64
#  36  geometry         7551 non-null   geometry
# dtypes: float64(25), geometry(1), object(11)
# memory usage: 2.2+ MB

# %%
geojoin.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
geojoin.to_file("Data/polygon_joined.geojson", driver='GeoJSON')
# Out:
# /Users/Nicole.lynn/opt/anaconda3/envs/UDS/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
geojoin.GEOID.is_unique
# Out:
# False

# %%
geojoin['GEOID'].value_counts()
# Out:
# 06037207102    243
# 06037207710    172
# 06037123301    166
# 06037265510    160
# 06037265202    159
#               ...
# 06037141400      1
# 06037265100      1
# 06037262100      1
# 06037261200      1
# 06037460800      1
# Name: GEOID, Length: 1149, dtype: int64

# %%
#getting count of how many listings in each census tract
count = geojoin.groupby('GEOID').count()['post title']

# %%
count.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1149 entries, 06037101110 to 06037980031
# Series name: post title
# Non-Null Count  Dtype
# --------------  -----
# 1149 non-null   int64
# dtypes: int64(1)
# memory usage: 18.0+ KB

# %%
#listing from biggest to smallest
listing_count= count.sort_values(ascending=False)

# %%
listing_count.name= 'listing_count'

# %%
listing_count= pd.DataFrame(listing_count)

# %%
listing_count.head()
# Out:
#              listing_count
# GEOID
# 06037207102            243
# 06037207710            172
# 06037123301            166
# 06037265510            160
# 06037265202            159

# %%
listing_count.describe()
# Out:
#        listing_count
# count    1149.000000
# mean        6.006963
# std        17.958672
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         3.000000
# max       243.000000

# %%
listing_count2 = listing_count[listing_count['listing_count']>=5]

# %%
listing_count2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 06037207102 to 06037123902
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_count  243 non-null    int64
# dtypes: int64(1)
# memory usage: 3.8+ KB

# %%
listing_count2.describe()
# Out:
#        listing_count
# count     243.000000
# mean       26.493827
# std        31.495686
# min         5.000000
# 25%         9.000000
# 50%        15.000000
# 75%        32.000000
# max       243.000000

# %%
permits= gpd.read_file('Data/CensusPlusPermits.geojson')

# %%
permits.head()
# Out:
#          GEOID  TotalPop  WhitePop  BlackorAA  AmInd_AKnative  Asian  \
# 0  06037274202    4284.0    3340.0       88.0             0.0  352.0
# 1  06037273902    4221.0    3707.0       76.0            13.0  162.0
# 2  06037273502    2861.0    2384.0      207.0            18.0   58.0
# 3  06037273402    2641.0    2432.0      157.0             0.0    5.0
# 4  06037273300    2915.0    2085.0      446.0             0.0   70.0
#
#    Hawaiian_PI  Other  EducTotal  Median HHI  ... EducDoct     PctNHW  \
# 0          0.0  382.0     3786.0    128766.0  ...    247.0  77.964519
# 1          0.0   36.0     3601.0    144924.0  ...     99.0  87.822791
# 2          0.0   45.0     2487.0     90161.0  ...     58.0  83.327508
# 3          0.0   12.0     2386.0     72258.0  ...     98.0  92.086331
# 4          0.0  223.0     2297.0     71823.0  ...     46.0  71.526587
#
#   PctBlackAA  PctAsian     pctPOC  PctBachelor  PctMasters  PctDoctorate  \
# 0   2.054155  8.216620  22.035481    34.970946   27.284733      6.524036
# 1   1.800521  3.837953  12.177209    43.043599   23.965565      2.749236
# 2   7.235232  2.027263  16.672492    44.873341   21.431444      2.332127
# 3   5.944718  0.189322   7.913669    40.067058   23.470243      4.107293
# 4  15.300172  2.401372  28.473413    47.757945   13.757074      2.002612
#
#    permit_count                                           geometry
# 0           8.0  POLYGON ((-118.46683 33.97905, -118.46654 33.9...
# 1          48.0  POLYGON ((-118.47136 33.98425, -118.47106 33.9...
# 2          28.0  POLYGON ((-118.47671 33.98745, -118.47504 33.9...
# 3          21.0  POLYGON ((-118.48334 33.99551, -118.48217 33.9...
# 4          54.0  POLYGON ((-118.47838 33.99813, -118.47816 33.9...
#
# [5 rows x 27 columns]

# %%
geojoin.price.isna().sum()
# Out:
# 767

# %%
# need to change it so I can get the mean
geojoin['price'] = geojoin['price'].str.replace(',','')

# %%
#changing it to numeric
geojoin['price']= geojoin['price'].apply(pd.to_numeric, errors='coerce')

# %%
geojoin.price.isna().sum()
# Out:
# 767

# %%
#getting the average price per tract
avg_price= geojoin.groupby('GEOID').mean()['price']

# %%
avg_price.isna().sum()
# Out:
# 663

# %%
print(len(avg_price))
# Out:
# 1149

# %%
med_price = geojoin.groupby('GEOID').median()['price']

# %%
newdf= listing_count2.join(avg_price)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 06037207102 to 06037123902
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_count  243 non-null    int64
#  1   price          243 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 13.8+ KB

# %%
newdf.columns=['listing_count','avg price']

# %%
newdf= newdf.join(med_price)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 06037207102 to 06037123902
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_count  243 non-null    int64
#  1   avg price      243 non-null    float64
#  2   price          243 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 15.7+ KB

# %%
newdf.columns=['listing_count','avg price','med price']

# %%
newdf.head()
# Out:
#              listing_count    avg price  med price
# GEOID
# 06037207102            243  2631.860082     2609.0
# 06037207710            172  2892.890244     2823.5
# 06037123301            166  2335.268293     1852.0
# 06037265510            160  3173.300000     2850.0
# 06037265202            159  3645.685535     3595.0

# %%
permits.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1149 entries, 0 to 1148
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GEOID           1149 non-null   object
#  1   TotalPop        1149 non-null   float64
#  2   WhitePop        1149 non-null   float64
#  3   BlackorAA       1149 non-null   float64
#  4   AmInd_AKnative  1149 non-null   float64
#  5   Asian           1149 non-null   float64
#  6   Hawaiian_PI     1149 non-null   float64
#  7   Other           1149 non-null   float64
#  8   EducTotal       1149 non-null   float64
#  9   Median HHI      1133 non-null   float64
#  10  NAME            1149 non-null   object
#  11  state           1149 non-null   object
#  12  county          1149 non-null   object
#  13  tract           1149 non-null   object
#  14  EducBachelor    1149 non-null   float64
#  15  EducMasters     1149 non-null   float64
#  16  EducProf        1149 non-null   float64
#  17  EducDoct        1149 non-null   float64
#  18  PctNHW          1140 non-null   float64
#  19  PctBlackAA      1140 non-null   float64
#  20  PctAsian        1140 non-null   float64
#  21  pctPOC          1140 non-null   float64
#  22  PctBachelor     1139 non-null   float64
#  23  PctMasters      1139 non-null   float64
#  24  PctDoctorate    1139 non-null   float64
#  25  permit_count    970 non-null    float64
#  26  geometry        1149 non-null   geometry
# dtypes: float64(21), geometry(1), object(5)
# memory usage: 242.5+ KB

# %%
fulldf= listing_count.join(avg_price)

# %%
fulldf= fulldf.join(med_price, rsuffix='_med')

# %%
fulldf.columns=['listing_count','avg price','med price']

# %%
fulldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1149 entries, 06037207102 to 06037980031
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_count  1149 non-null   int64
#  1   avg price      486 non-null    float64
#  2   med price      486 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 68.2+ KB

# %%
#Now I'm going to try to do square foot
geojoin.sqft.describe()
# Out:
# count     5633.00000
# mean       851.07314
# std        798.63148
# min          1.00000
# 25%        600.00000
# 50%        765.00000
# 75%       1000.00000
# max      50002.00000
# Name: sqft, dtype: float64

# %%
avg_sqft = geojoin.groupby('GEOID').mean()['sqft']

# %%
avg_sqft.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1149 entries, 06037101110 to 06037980031
# Series name: sqft
# Non-Null Count  Dtype
# --------------  -----
# 427 non-null    float64
# dtypes: float64(1)
# memory usage: 18.0+ KB

# %%
med_sqft = geojoin.groupby('GEOID').median()['sqft']

# %%
newdf= newdf.join(avg_sqft)

# %%
newdf= newdf.join(med_sqft, rsuffix='_med')

# %%
newdf.head()
# Out:
#              listing_count    avg price  med price        sqft  sqft_med
# GEOID
# 06037207102            243  2631.860082     2609.0  822.586777     842.0
# 06037207710            172  2892.890244     2823.5  876.868750     814.5
# 06037123301            166  2335.268293     1852.0  659.007299     575.0
# 06037265510            160  3173.300000     2850.0  681.060606     500.0
# 06037265202            159  3645.685535     3595.0  752.554545     712.5

# %%
newdf.columns=['listing count','avg price','med price','avg sqft','med sqft']

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, 06037207102 to 06037123902
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing count  243 non-null    int64
#  1   avg price      243 non-null    float64
#  2   med price      243 non-null    float64
#  3   avg sqft       232 non-null    float64
#  4   med sqft       232 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 19.5+ KB

# %%
permits.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1149 entries, 0 to 1148
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GEOID           1149 non-null   object
#  1   TotalPop        1149 non-null   float64
#  2   WhitePop        1149 non-null   float64
#  3   BlackorAA       1149 non-null   float64
#  4   AmInd_AKnative  1149 non-null   float64
#  5   Asian           1149 non-null   float64
#  6   Hawaiian_PI     1149 non-null   float64
#  7   Other           1149 non-null   float64
#  8   EducTotal       1149 non-null   float64
#  9   Median HHI      1133 non-null   float64
#  10  NAME            1149 non-null   object
#  11  state           1149 non-null   object
#  12  county          1149 non-null   object
#  13  tract           1149 non-null   object
#  14  EducBachelor    1149 non-null   float64
#  15  EducMasters     1149 non-null   float64
#  16  EducProf        1149 non-null   float64
#  17  EducDoct        1149 non-null   float64
#  18  PctNHW          1140 non-null   float64
#  19  PctBlackAA      1140 non-null   float64
#  20  PctAsian        1140 non-null   float64
#  21  pctPOC          1140 non-null   float64
#  22  PctBachelor     1139 non-null   float64
#  23  PctMasters      1139 non-null   float64
#  24  PctDoctorate    1139 non-null   float64
#  25  permit_count    970 non-null    float64
#  26  geometry        1149 non-null   geometry
# dtypes: float64(21), geometry(1), object(5)
# memory usage: 242.5+ KB

# %%
grand_db = newdf.join(permits.set_index('GEOID'))

# %%
grand_db.head()
# Out:
#              listing count    avg price  med price    avg sqft  med sqft  \
# GEOID
# 06037207102            243  2631.860082     2609.0  822.586777     842.0
# 06037207710            172  2892.890244     2823.5  876.868750     814.5
# 06037123301            166  2335.268293     1852.0  659.007299     575.0
# 06037265510            160  3173.300000     2850.0  681.060606     500.0
# 06037265202            159  3645.685535     3595.0  752.554545     712.5
#
#              TotalPop  WhitePop  BlackorAA  AmInd_AKnative   Asian  ...  \
# GEOID                                                               ...
# 06037207102    2926.0     323.0      220.0            74.0  1695.0  ...
# 06037207710    4667.0    2028.0      605.0             0.0  1689.0  ...
# 06037123301    4530.0    2309.0      210.0            16.0  1241.0  ...
# 06037265510    4663.0    2556.0      131.0            42.0  1747.0  ...
# 06037265202    3981.0    2521.0       17.0             0.0   891.0  ...
#
#              EducDoct     PctNHW  PctBlackAA   PctAsian     pctPOC  \
# GEOID
# 06037207102      37.0  11.038961    7.518797  57.928913  88.961039
# 06037207710     315.0  43.454039   12.963360  36.190272  56.545961
# 06037123301       0.0  50.971302    4.635762  27.395143  49.028698
# 06037265510     259.0  54.814497    2.809350  37.465151  45.185503
# 06037265202     139.0  63.325798    0.427028  22.381311  36.674202
#
#             PctBachelor PctMasters PctDoctorate  permit_count  \
# GEOID
# 06037207102   20.827770   4.494882     1.646640           9.0
# 06037207710   41.589014  21.505640     7.724375          23.0
# 06037123301   23.900338   8.643494     0.000000          13.0
# 06037265510   31.620405  32.820705     9.714929          11.0
# 06037265202   28.198957  30.766145     5.575612           4.0
#
#                                                       geometry
# GEOID
# 06037207102  POLYGON ((-118.24296 34.05739, -118.24278 34.0...
# 06037207710  POLYGON ((-118.27257 34.04307, -118.27241 34.0...
# 06037123301  POLYGON ((-118.40544 34.20713, -118.40537 34.2...
# 06037265510  POLYGON ((-118.44549 34.05835, -118.44396 34.0...
# 06037265202  POLYGON ((-118.44705 34.06365, -118.44534 34.0...
#
# [5 rows x 31 columns]

# %%
#turning it into a geo dataframe!
from geopandas import GeoDataFrame

grand_db = GeoDataFrame(grand_db, crs="EPSG:4326", geometry=grand_db.geometry)

# %%
grand_db.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 243 entries, 06037207102 to 06037123902
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   listing count   243 non-null    int64
#  1   avg price       243 non-null    float64
#  2   med price       243 non-null    float64
#  3   avg sqft        232 non-null    float64
#  4   med sqft        232 non-null    float64
#  5   TotalPop        243 non-null    float64
#  6   WhitePop        243 non-null    float64
#  7   BlackorAA       243 non-null    float64
#  8   AmInd_AKnative  243 non-null    float64
#  9   Asian           243 non-null    float64
#  10  Hawaiian_PI     243 non-null    float64
#  11  Other           243 non-null    float64
#  12  EducTotal       243 non-null    float64
#  13  Median HHI      242 non-null    float64
#  14  NAME            243 non-null    object
#  15  state           243 non-null    object
#  16  county          243 non-null    object
#  17  tract           243 non-null    object
#  18  EducBachelor    243 non-null    float64
#  19  EducMasters     243 non-null    float64
#  20  EducProf        243 non-null    float64
#  21  EducDoct        243 non-null    float64
#  22  PctNHW          242 non-null    float64
#  23  PctBlackAA      242 non-null    float64
#  24  PctAsian        242 non-null    float64
#  25  pctPOC          242 non-null    float64
#  26  PctBachelor     242 non-null    float64
#  27  PctMasters      242 non-null    float64
#  28  PctDoctorate    242 non-null    float64
#  29  permit_count    237 non-null    float64
#  30  geometry        243 non-null    geometry
# dtypes: float64(25), geometry(1), int64(1), object(4)
# memory usage: 68.9+ KB

# %%
grand_db.plot()
# Out:
# <AxesSubplot:>

# %%
grand_db.to_file("Data/Grand_Gdf.geojson", driver='GeoJSON')

# %%
grand_db[grand_db['listing count']>50].plot()
# Out:
# <AxesSubplot:>

# %%
import contextily as ctx
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))


grand_db.to_crs('EPSG:3857').plot(column = 'listing count',
              ax=ax,
              legend = True,
              cmap = 'Blues_r')

ctx.add_basemap(ax=ax,source=ctx.providers.CartoDB.Positron)

# %%
fig, ax = plt.subplots(figsize=(10,10))


grand_db.to_crs('EPSG:3857').plot(column = 'avg price',
              ax=ax,
              legend = True,
              cmap = 'Blues_r')

ctx.add_basemap(ax=ax,source=ctx.providers.CartoDB.Positron)

# %%
fig, ax = plt.subplots(figsize=(10,10))


grand_db.to_crs('EPSG:3857').plot(column = 'permit_count',
              ax=ax,
              legend = True,
              cmap = 'Blues_r')

ctx.add_basemap(ax=ax,source=ctx.providers.CartoDB.Positron)
