# %%
import requests
import json
import geopandas as gpd
import pandas as pd

# %%
# pulling in permit data from permit acquisition shapefile
permitdata=gpd.read_file('/Users/alliepadgett/Documents/GitHub/Housing_Modeling/Data/permit_gdf.geojson')

# %%
# checking everything!
permitdata.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 27742 entries, 0 to 27741
# Data columns (total 58 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   assessor_parcel                          27709 non-null  object
#  1   zip_code                                 27742 non-null  object
#  2   location_1_address                       27742 non-null  object
#  3   work_description                         27742 non-null  object
#  4   applicant_address_3                      21295 non-null  object
#  5   floor_area_l_a_zoning_code_definition    26987 non-null  object
#  6   address_fraction_end                     2317 non-null   object
#  7   project_number                           135 non-null    object
#  8   suffix_direction                         41 non-null     object
#  9   of_stories                               27735 non-null  object
#  10  address_start                            27742 non-null  object
#  11  permit_category                          27742 non-null  object
#  12  status_date                              27742 non-null  object
#  13  unit_range_end                           551 non-null    object
#  14  pcis_permit                              27742 non-null  object
#  15  address_end                              27742 non-null  object
#  16  issue_date                               27742 non-null  object
#  17  street_name                              27742 non-null  object
#  18  contractor_address                       16579 non-null  object
#  19  license                                  27742 non-null  object
#  20  contractors_business_name                27716 non-null  object
#  21  assessor_page                            27709 non-null  object
#  22  block                                    6107 non-null   object
#  23  applicant_first_name                     26680 non-null  object
#  24  location_1_city                          27742 non-null  object
#  25  applicant_last_name                      23987 non-null  object
#  26  valuation                                27739 non-null  object
#  27  unit_range_start                         2493 non-null   object
#  28  tract                                    27610 non-null  object
#  29  address_fraction_start                   655 non-null    object
#  30  location_1_state                         27742 non-null  object
#  31  principal_last_name                      16652 non-null  object
#  32  contractor_city                          16255 non-null  object
#  33  latest_status                            27742 non-null  object
#  34  census_tract                             27737 non-null  object
#  35  lot                                      27505 non-null  object
#  36  floor_area_l_a_building_code_definition  27737 non-null  object
#  37  applicant_address_1                      21759 non-null  object
#  38  street_suffix                            27338 non-null  object
#  39  applicant_business_name                  3130 non-null   object
#  40  street_direction                         27661 non-null  object
#  41  permit_type                              27742 non-null  object
#  42  occupancy                                743 non-null    object
#  43  location_1_zip                           27742 non-null  object
#  44  principal_middle_name                    11979 non-null  object
#  45  assessor_book                            27709 non-null  object
#  46  of_residential_dwelling_units            17427 non-null  object
#  47  principal_first_name                     16699 non-null  object
#  48  zone                                     27710 non-null  object
#  49  initiating_office                        27742 non-null  object
#  50  license_type                             27742 non-null  object
#  51  event_code                               0 non-null      object
#  52  reference_old_permit                     27740 non-null  object
#  53  contractor_state                         16252 non-null  object
#  54  license_expiration_date                  20020 non-null  object
#  55  applicant_address_2                      6684 non-null   object
#  56  permit_sub_type                          27742 non-null  object
#  57  geometry                                 27742 non-null  geometry
# dtypes: geometry(1), object(57)
# memory usage: 12.3+ MB

# %%
# pulling in clipped LA shapefile with census data
lacensus=gpd.read_file('/Users/alliepadgett/Documents/GitHub/Housing_Modeling/Data/lacounty_clipped.geojson')

# %%
# setting projections and spatial joining census data to permit data to get tracts for each permit
# lacensus = clipped shapefile w tracts & census variables
# permitdata = permit info
# permitcensus = permit info w/ tracts assigned
permitdata=permitdata.set_crs('EPSG:4326')
lacensus=lacensus.to_crs('EPSG:4326')
permitcensus = gpd.sjoin(permitdata, lacensus, how="left", predicate='intersects')
permitcensus.head()
# Out:
#   assessor_parcel zip_code location_1_address  \
# 0             029    90038
# 1             013    90007
# 2             033    91326
# 3             008    90066
# 4             010    90018
#
#                                     work_description applicant_address_3  \
# 0  New 3-Story Duplex w/Attached 2-Car Garage Eac...                None
# 1  BUILDING "B" - NEW (3) STORY DUPLEX BUILDING A...        LAWNDALE, CA
# 2  TWO STORY SFD WITH ATTACHED 3 CAR GARAGE _STAN...        PORTER RANCH
# 3          New SFD with attached garage and recroom.                None
# 4    NEW TWO STORY DUPLEX WITH OPEN PARKING AT REAR.                None
#
#   floor_area_l_a_zoning_code_definition address_fraction_end project_number  \
# 0                                  2328                 None           None
# 1                                  4963                  1/2           None
# 2                                  4957                 None           None
# 3                                  5994                 None           None
# 4                                  2444                  1/2           None
#
#   suffix_direction of_stories  ... EducMasters EducProf EducDoct     PctNHW  \
# 0             None          3  ...       312.0    142.0     27.0  84.038737
# 1             None          3  ...       205.0     18.0     30.0  26.166877
# 2             None          2  ...       987.0    474.0    119.0  39.121143
# 3             None          2  ...       446.0    287.0     69.0  74.333770
# 4             None          2  ...         6.0     59.0      0.0  31.139420
#
#   PctBlackAA   PctAsian     pctPOC PctBachelor PctMasters PctDoctorate
# 0   0.645624   6.420373  15.961263   50.249660  20.608261     1.225601
# 1  18.489818  18.760137  73.833123   15.025413   7.083863     0.952986
# 2   7.853613  48.176840  60.878857   33.094340  27.566038     2.245283
# 3   0.917431   5.635649  25.666230   36.698622  21.959257     2.067106
# 4  27.270583   5.425808  68.860580   21.167883   2.497119     0.000000
#
# [5 rows x 84 columns]

# %%
# make sure parcels are unique before using in a groupby
pd.Series('permitcensus.assessor_parcel').is_unique
# Out:
# True

# %%
# groupby to get number of permits per tract
permit_counts=permitcensus.groupby(['GEOID']).count()['assessor_parcel']
permit_counts
# Out:
# GEOID
# 06037101110    48
# 06037101122    25
# 06037101210    18
# 06037101220    15
# 06037101300    26
#                ..
# 06037980021     1
# 06037980022     1
# 06037980024     7
# 06037980028    69
# 06037980031    26
# Name: assessor_parcel, Length: 970, dtype: int64

# %%
# join permit counts back to census shapefile
permitcensus.set_index('GEOID', inplace=True)

permit_counts.name = 'permit_count'
censuspermitcounts = lacensus.join(permit_counts, on = 'GEOID', how='left')
censuspermitcounts.head()
# Out:
#          GEOID  TotalPop  WhitePop  BlackorAA  AmInd_AKnative  Asian  \
# 0  06037274202    4284.0    3340.0       88.0             0.0  352.0
# 1  06037273902    4221.0    3707.0       76.0            13.0  162.0
# 2  06037273502    2861.0    2384.0      207.0            18.0   58.0
# 3  06037273402    2641.0    2432.0      157.0             0.0    5.0
# 4  06037273300    2915.0    2085.0      446.0             0.0   70.0
#
#    Hawaiian_PI  Other  EducTotal  Median HHI  ... EducDoct     PctNHW  \
# 0          0.0  382.0     3786.0    128766.0  ...    247.0  77.964519
# 1          0.0   36.0     3601.0    144924.0  ...     99.0  87.822791
# 2          0.0   45.0     2487.0     90161.0  ...     58.0  83.327508
# 3          0.0   12.0     2386.0     72258.0  ...     98.0  92.086331
# 4          0.0  223.0     2297.0     71823.0  ...     46.0  71.526587
#
#   PctBlackAA  PctAsian     pctPOC  PctBachelor  PctMasters  PctDoctorate  \
# 0   2.054155  8.216620  22.035481    34.970946   27.284733      6.524036
# 1   1.800521  3.837953  12.177209    43.043599   23.965565      2.749236
# 2   7.235232  2.027263  16.672492    44.873341   21.431444      2.332127
# 3   5.944718  0.189322   7.913669    40.067058   23.470243      4.107293
# 4  15.300172  2.401372  28.473413    47.757945   13.757074      2.002612
#
#                                             geometry  permit_count
# 0  POLYGON ((-118.46683 33.97905, -118.46654 33.9...           8.0
# 1  POLYGON ((-118.47136 33.98425, -118.47106 33.9...          48.0
# 2  POLYGON ((-118.47671 33.98745, -118.47504 33.9...          28.0
# 3  POLYGON ((-118.48334 33.99551, -118.48217 33.9...          21.0
# 4  POLYGON ((-118.47838 33.99813, -118.47816 33.9...          54.0
#
# [5 rows x 27 columns]

# %%
censuspermitcounts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1149 entries, 0 to 1148
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GEOID           1149 non-null   object
#  1   TotalPop        1149 non-null   float64
#  2   WhitePop        1149 non-null   float64
#  3   BlackorAA       1149 non-null   float64
#  4   AmInd_AKnative  1149 non-null   float64
#  5   Asian           1149 non-null   float64
#  6   Hawaiian_PI     1149 non-null   float64
#  7   Other           1149 non-null   float64
#  8   EducTotal       1149 non-null   float64
#  9   Median HHI      1133 non-null   float64
#  10  NAME            1149 non-null   object
#  11  state           1149 non-null   object
#  12  county          1149 non-null   object
#  13  tract           1149 non-null   object
#  14  EducBachelor    1149 non-null   float64
#  15  EducMasters     1149 non-null   float64
#  16  EducProf        1149 non-null   float64
#  17  EducDoct        1149 non-null   float64
#  18  PctNHW          1140 non-null   float64
#  19  PctBlackAA      1140 non-null   float64
#  20  PctAsian        1140 non-null   float64
#  21  pctPOC          1140 non-null   float64
#  22  PctBachelor     1139 non-null   float64
#  23  PctMasters      1139 non-null   float64
#  24  PctDoctorate    1139 non-null   float64
#  25  geometry        1149 non-null   geometry
#  26  permit_count    970 non-null    float64
# dtypes: float64(21), geometry(1), object(5)
# memory usage: 242.5+ KB

# %%
# renaming for clarity
CensusPlusPermits = censuspermitcounts

# %%
# saving down the file, to bring into other notebooks!

CensusPlusPermits.to_file("Data/CensusPlusPermits.geojson", driver='GeoJSON')
# Out:
# /Users/alliepadgett/opt/anaconda3/envs/uds/lib/python3.8/site-packages/geopandas/io/file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
