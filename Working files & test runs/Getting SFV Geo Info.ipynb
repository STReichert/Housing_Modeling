# %%
import pandas as pd
import requests
from requests import get
from bs4 import BeautifulSoup
import random
import time


sfv_apts = pd.read_csv('Data/sfv_listings_May24.csv')
sfv_apts.head()
# Out:
#    Unnamed: 0            posted  \
# 0           0  2022-05-24 17:35
# 1           1  2022-05-24 17:35
# 2           2  2022-05-24 17:34
# 3           3  2022-05-24 17:32
# 4           4  2022-05-24 17:29
#
#                                       neighborhood  \
# 0   (17171 West Roscoe Boulevard, Los Angeles, CA)
# 1                                (NORTH HOLLYWOOD)
# 2                                (NORTH HOLLYWOOD)
# 3         (6530 Independence Ave. Canoga Park, CA)
# 4                                    (Lake Balboa)
#
#                                           post title  number bedrooms    sqft  \
# 0  Evening courtesy patrol, Mirrored wardrobe, On...              1.0   650.0
# 1  HOUSE FOR LEASE! WASHER DRYER, WD FLR, CENTRAL...              4.0     NaN
# 2  BRAND NEW BUILT TOWNHOUSE BACKHOUSE,WASHER DRY...              3.0  1200.0
# 3  2 Bedroom with pool, spa, BBQ, firepit, gym, C...              2.0   792.0
# ...

# %%
#sfv_apts.drop(columns=['latlon', 'Unnamed: 0'], inplace=True)
sfv_apts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3000 non-null   int64
#  1   posted           3000 non-null   object
#  2   neighborhood     3000 non-null   object
#  3   post title       3000 non-null   object
#  4   number bedrooms  2530 non-null   float64
#  5   sqft             2646 non-null   float64
#  6   URL              3000 non-null   object
#  7   price            2965 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 187.6+ KB

# %%
# this code is from Seth!
import requests

def get_latlong(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content)
    try:
        link = soup.find_all('div', class_='viewposting')
        lat = link[0]['data-latitude']
        long = link[0]['data-longitude']
        time.sleep(random.uniform(.5,3))
    #this code could be used to randomize the time between calls to craigslist and slow down the scraper 
    #It definitely helps to keep from getting blocked/throttled
        return [lat, long]
    except:
        return [None, None]

# %%
test_lat, test_long = get_latlong(sfv_apts.URL.loc[5])
print('lat is {}, long is {}'.format(test_lat, test_long))
# Out:
# lat is 34.377500, long is -118.613100

# %%
#

# %%
sfv_apts.sample(10)
# Out:
#       Unnamed: 0            posted                               neighborhood  \
# 2101        2101  2022-05-23 08:32   (22219 Summit Vue Lane, Los Angeles, CA)
# 1439        1439  2022-05-23 15:49                                  (Tujunga)
# 502          502  2022-05-24 12:24                                  (Burbank)
# 2929        2929  2022-05-21 12:59                             (Sherman Oaks)
# 1505        1505  2022-05-23 15:00                                  (Burbank)
# 2602        2602  2022-05-22 09:14                                  (Burbank)
# 2834        2834  2022-05-21 15:54                              (Los Angeles)
# 972          972  2022-05-24 08:11                                  (TUJUNGA)
# 1962        1962  2022-05-23 09:54      (Central  location in Valley Village)
# 1290        1290  2022-05-23 17:06                          (North Hollywood)
#
#                                              post title  number bedrooms  \
# ...

# %%
sfv_apts['y'] = sfv_apts['latlon'].apply(lambda x: x[0])
sfv_apts['x'] = sfv_apts['latlon'].apply(lambda x: x[1])

# %%
sfv_apts.head()
# Out:
#    Unnamed: 0            posted        neighborhood  \
# 0           0  2022-05-22 09:49          (Van Nuys)
# 1           1  2022-05-22 09:49   (North Hollywood)
# 2           2  2022-05-22 09:49        (Northridge)
# 3           3  2022-05-22 09:48          (Glendale)
# 4           4  2022-05-22 09:47       (Toluca Lake)
#
#                                           post title  number bedrooms   sqft  \
# 0  ❖ Nice Studio in Van Nuys *Full Kitchen *2 Clo...              NaN  425.0
# 1  Renovated Studio in NoHo +Full Kitchen +Plank ...              NaN  500.0
# 2  2+2 in Northridge +SS Appliances +Quartz Count...              2.0  945.0
# 3  Glendale Newly Renovated 2+1 with SS Appliance...              2.0  875.0
# 4  LIVE IN BEAUTIFUL TOLUCA LAKE-SPACIOUS 1+1 & L...              1.0  847.0
#
#                                                  URL  price  \
# 0  https://losangeles.craigslist.org/sfv/apa/d/va...  1,575
# 1  https://losangeles.craigslist.org/sfv/apa/d/to...  1,795
# ...

# %%
sfv_apts.to_csv('Data/la_apts_SFV_geometry_May25.csv')

# %%
sfv_apts.latlon.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       [34.193804, -118.466316]
# 1       [34.172111, -118.380983]
# 2       [34.250203, -118.521639]
# 3       [34.133366, -118.262479]
# 4       [34.151000, -118.366300]
#                   ...
# 3115    [34.205700, -118.400100]
# 3116    [34.236700, -118.546600]
# 3117    [34.152600, -118.432200]
# 3118    [34.816019, -119.003799]
# 3119    [34.413200, -118.426000]
# Name: latlon, Length: 3120, dtype: object>

# %%
sfv_apts.URL.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       https://losangeles.craigslist.org/sfv/apa/d/va...
# 1       https://losangeles.craigslist.org/sfv/apa/d/to...
# 2       https://losangeles.craigslist.org/sfv/apa/d/no...
# 3       https://losangeles.craigslist.org/sfv/apa/d/gl...
# 4       https://losangeles.craigslist.org/sfv/apa/d/no...
#                               ...
# 3115    https://losangeles.craigslist.org/sfv/apa/d/no...
# 3116    https://losangeles.craigslist.org/sfv/apa/d/no...
# 3117    https://losangeles.craigslist.org/sfv/apa/d/sh...
# 3118    https://losangeles.craigslist.org/sfv/apa/d/fr...
# 3119    https://losangeles.craigslist.org/sfv/apa/d/ca...
# Name: URL, Length: 3120, dtype: object>

# %%
sfv_apts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3120 non-null   int64
#  1   posted           3120 non-null   object
#  2   neighborhood     3120 non-null   object
#  3   post title       3120 non-null   object
#  4   number bedrooms  2522 non-null   float64
#  5   sqft             2574 non-null   float64
#  6   URL              3120 non-null   object
#  7   price            3068 non-null   object
#  8   latlon           3120 non-null   object
#  9   y                3042 non-null   object
#  10  x                3042 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 268.2+ KB

# %%
sfv_apts.URL.value_counts().max()
# Out:
# 26

# %%
sfv_apts.URL.value_counts().sort_values(ascending=False)
# Out:
# https://losangeles.craigslist.org/sfv/apa/d/van-nuys-nice-studio-in-van-nuys-full/7486904059.html      26
# https://losangeles.craigslist.org/sfv/apa/d/toluca-lake-renovated-studio-in-noho/7486903910.html       26
# https://losangeles.craigslist.org/sfv/apa/d/northridge-22-in-northridge-ss/7486903708.html             26
# https://losangeles.craigslist.org/sfv/apa/d/glendale-glendale-newly-renovated-21/7486903565.html       26
# https://losangeles.craigslist.org/sfv/apa/d/north-hollywood-live-in-beautiful/7486902917.html          26
#                                                                                                        ..
# https://losangeles.craigslist.org/sfv/apa/d/northridge-bed-plush-designer-carpeting/7479030270.html    26
# https://losangeles.craigslist.org/sfv/apa/d/sherman-oaks-stainless-steel-appliances/7484415221.html    26
# https://losangeles.craigslist.org/sfv/apa/d/frazier-park-beautiful-mtn-325-home-in/7480427965.html     26
# ...

# %%
sfv_apts['post title'].nunique()
# Out:
# 112

# %%
import pandas as pd
sfv_apts = pd.read_csv('data/la_apts_SFV_geometry_May25.csv')
sfv_apts.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0            posted  \
# 0             0           0  2022-05-24 17:35
# 1             1           1  2022-05-24 17:35
# 2             2           2  2022-05-24 17:34
# 3             3           3  2022-05-24 17:32
# 4             4           4  2022-05-24 17:29
#
#                                       neighborhood  \
# 0   (17171 West Roscoe Boulevard, Los Angeles, CA)
# 1                                (NORTH HOLLYWOOD)
# 2                                (NORTH HOLLYWOOD)
# 3         (6530 Independence Ave. Canoga Park, CA)
# 4                                    (Lake Balboa)
#
#                                           post title  number bedrooms    sqft  \
# 0  Evening courtesy patrol, Mirrored wardrobe, On...              1.0   650.0
# 1  HOUSE FOR LEASE! WASHER DRYER, WD FLR, CENTRAL...              4.0     NaN
# 2  BRAND NEW BUILT TOWNHOUSE BACKHOUSE,WASHER DRY...              3.0  1200.0
# ...

# %%
sfv_apts['latlon']= sfv_apts['latlon'].str.replace('\'','', regex=True)

# %%
sfv_apts['latlon']=sfv_apts['latlon'].astype(object)

# %%
sfv_apts.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0            posted  \
# 0             0           0  2022-05-24 17:35
# 1             1           1  2022-05-24 17:35
# 2             2           2  2022-05-24 17:34
# 3             3           3  2022-05-24 17:32
# 4             4           4  2022-05-24 17:29
#
#                                       neighborhood  \
# 0   (17171 West Roscoe Boulevard, Los Angeles, CA)
# 1                                (NORTH HOLLYWOOD)
# 2                                (NORTH HOLLYWOOD)
# 3         (6530 Independence Ave. Canoga Park, CA)
# 4                                    (Lake Balboa)
#
#                                           post title  number bedrooms    sqft  \
# 0  Evening courtesy patrol, Mirrored wardrobe, On...              1.0   650.0
# 1  HOUSE FOR LEASE! WASHER DRYER, WD FLR, CENTRAL...              4.0     NaN
# 2  BRAND NEW BUILT TOWNHOUSE BACKHOUSE,WASHER DRY...              3.0  1200.0
# ...

# %%
sfv_apts= sfv_apts.drop(columns=['y', 'x'])

# %%
sfv_apts['y'] = sfv_apts['latlon'].apply(lambda x: x[0])
sfv_apts['x'] = sfv_apts['latlon'].apply(lambda x: x[1])

# %%
sfv_apts.sample(60)
# Out:
#       Unnamed: 0.1  Unnamed: 0            posted  \
# 422            422         422  2022-05-24 13:22
# 2724          2724        2724  2022-05-21 19:02
# 1938          1938        1938  2022-05-23 10:10
# 2923          2923        2923  2022-05-21 13:10
# 2972          2972        2972  2022-05-21 11:27
# 26              26          26  2022-05-24 17:11
# 2019          2019        2019  2022-05-23 09:24
# 2110          2110        2110  2022-05-23 08:13
# 163            163         163  2022-05-24 16:03
# 1117          1117        1117  2022-05-23 21:29
# 1439          1439        1439  2022-05-23 15:49
# 2271          2271        2271  2022-05-22 19:04
# 32              32          32  2022-05-24 17:08
# 2041          2041        2041  2022-05-23 09:14
# 2145          2145        2145  2022-05-23 05:34
# 0                0           0  2022-05-24 17:35
# 1998          1998        1998  2022-05-23 09:32
# 834            834         834  2022-05-24 09:42
# ...

# %%
sfv_apts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0.1     3000 non-null   int64
#  1   Unnamed: 0       3000 non-null   int64
#  2   posted           3000 non-null   object
#  3   neighborhood     3000 non-null   object
#  4   post title       3000 non-null   object
#  5   number bedrooms  2530 non-null   float64
#  6   sqft             2646 non-null   float64
#  7   URL              3000 non-null   object
#  8   price            2965 non-null   object
#  9   latlon           3000 non-null   object
#  10  y                3000 non-null   object
#  11  x                3000 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 281.4+ KB
